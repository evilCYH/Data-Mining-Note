# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
iris = pd.read_csv('./data/iris.csv')
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
y1 = iris[iris['Species'] == 'setosa']['Sepal.Length']
y2 = iris[iris['Species'] == 'versicolor']['Sepal.Length']
y3 = iris[iris['Species'] == 'virginica']['Sepal.Length']

x = np.linspace(1,50,50)

plt.figure(figsize=(8,4),dpi=150)

ax1 = plt.subplot(311)
plt.plot(x,y1,color='red')
ax2 = plt.subplot(312)
plt.plot(x,y2,color='blue')
ax3 = plt.subplot(313)
plt.plot(x,y3,color='green')
plt.subplots_adjust(hspace=0.4)

plt.figure(figsize=(8,4),dpi=150)
plt.title("Sepal-Length comparison")
plt.plot(x,y1,color='red',label='setosa')
plt.plot(x,y2,color='blue',label='versicolor')
plt.plot(x,y3,color='green',label='virginica')
plt.legend()

plt.show()

# %%
y4 = iris[iris['Species'] == 'setosa']['Sepal.Width']
y5 = iris[iris['Species'] == 'versicolor']['Sepal.Width']
y6 = iris[iris['Species'] == 'virginica']['Sepal.Width']

x = np.linspace(1,50,50)

plt.figure(figsize=(8,4),dpi=150)

ax1 = plt.subplot(311)
plt.plot(x,y4,color='red')
ax2 = plt.subplot(312)
plt.plot(x,y5,color='blue')
ax3 = plt.subplot(313)
plt.plot(x,y6,color='green')
plt.subplots_adjust(hspace=0.4)

plt.figure(figsize=(8,4),dpi=150)
plt.title("Sepal-Width comparison")
plt.plot(x,y4,color='red',label='setosa')
plt.plot(x,y5,color='blue',label='versicolor')
plt.plot(x,y6,color='green',label='virginica')
plt.legend()

plt.show()

# %%
y7 = iris[iris['Species'] == 'setosa']['Petal.Length']
y8 = iris[iris['Species'] == 'versicolor']['Petal.Length']
y9 = iris[iris['Species'] == 'virginica']['Petal.Length']

x = np.linspace(1,50,50)

plt.figure(figsize=(8,4),dpi=150)

ax1 = plt.subplot(311)
plt.plot(x,y7,color='red')
ax2 = plt.subplot(312)
plt.plot(x,y8,color='blue')
ax3 = plt.subplot(313)
plt.plot(x,y9,color='green')
plt.subplots_adjust(hspace=0.4)

plt.figure(figsize=(8,4),dpi=150)
plt.title("Petal-Length comparison")
plt.plot(x,y7,color='red',label='setosa')
plt.plot(x,y8,color='blue',label='versicolor')
plt.plot(x,y9,color='green',label='virginica')
plt.legend()

plt.show()

# %%
y10 = iris[iris['Species'] == 'setosa']['Petal.Width']
y11 = iris[iris['Species'] == 'versicolor']['Petal.Width']
y12 = iris[iris['Species'] == 'virginica']['Petal.Width']

x = np.linspace(1,50,50)

plt.figure(figsize=(8,4),dpi=150)

ax1 = plt.subplot(311)
plt.plot(x,y10,color='red')
ax2 = plt.subplot(312)
plt.plot(x,y11,color='blue')
ax3 = plt.subplot(313)
plt.plot(x,y12,color='green')
plt.subplots_adjust(hspace=0.4)

plt.figure(figsize=(8,4),dpi=150)
plt.title("Petal-Width comparison")
plt.plot(x,y10,color='red',label='setosa')
plt.plot(x,y11,color='blue',label='versicolor')
plt.plot(x,y12,color='green',label='virginica')
plt.legend()

plt.show()
